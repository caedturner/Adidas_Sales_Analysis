# %%
# Import Dependancies
import pandas as pd

# %%
# Read CSV 
df = pd.read_csv('/Users/caed/Desktop/Post/Adidas/Adidas US Sales Datasets.csv')

# %%
df
# Out:
#        Unnamed: 0             Unnamed: 1    Unnamed: 2 Unnamed: 3  \
# 0             NaN  Adidas Sales Database           NaN        NaN
# 1             NaN                    NaN           NaN        NaN
# 2             NaN                    NaN           NaN        NaN
# 3        Retailer            Retailer ID  Invoice Date     Region
# 4     Foot Locker                1185732        1/1/20  Northeast
# ...           ...                    ...           ...        ...
# 9647  Foot Locker                1185732       1/24/21  Northeast
# 9648  Foot Locker                1185732       1/24/21  Northeast
# 9649  Foot Locker                1185732       2/22/21  Northeast
# 9650  Foot Locker                1185732       2/22/21  Northeast
# 9651  Foot Locker                1185732       2/22/21  Northeast
#
#          Unnamed: 4  Unnamed: 5               Unnamed: 6      Unnamed: 7  \
# 0               NaN         NaN                      NaN             NaN
# ...

# %%
# Drop null values
df.dropna()
# Out:
#        Unnamed: 0   Unnamed: 1    Unnamed: 2 Unnamed: 3     Unnamed: 4  \
# 3        Retailer  Retailer ID  Invoice Date     Region          State
# 4     Foot Locker      1185732        1/1/20  Northeast       New York
# 5     Foot Locker      1185732        1/2/20  Northeast       New York
# 6     Foot Locker      1185732        1/3/20  Northeast       New York
# 7     Foot Locker      1185732        1/4/20  Northeast       New York
# ...           ...          ...           ...        ...            ...
# 9647  Foot Locker      1185732       1/24/21  Northeast  New Hampshire
# 9648  Foot Locker      1185732       1/24/21  Northeast  New Hampshire
# 9649  Foot Locker      1185732       2/22/21  Northeast  New Hampshire
# 9650  Foot Locker      1185732       2/22/21  Northeast  New Hampshire
# 9651  Foot Locker      1185732       2/22/21  Northeast  New Hampshire
#
#       Unnamed: 5                 Unnamed: 6      Unnamed: 7  Unnamed: 8  \
# ...

# %%
# Make row 3 the header of the DatFrame
header_row = df.iloc[3]

# %%
df2 = pd.DataFrame(df.values[4:], columns=header_row)
df2
# Out:
# 3        Retailer Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker     1185732       1/1/20  Northeast       New York
# 1     Foot Locker     1185732       1/2/20  Northeast       New York
# 2     Foot Locker     1185732       1/3/20  Northeast       New York
# 3     Foot Locker     1185732       1/4/20  Northeast       New York
# 4     Foot Locker     1185732       1/5/20  Northeast       New York
# ...           ...         ...          ...        ...            ...
# 9643  Foot Locker     1185732      1/24/21  Northeast  New Hampshire
# 9644  Foot Locker     1185732      1/24/21  Northeast  New Hampshire
# 9645  Foot Locker     1185732      2/22/21  Northeast  New Hampshire
# 9646  Foot Locker     1185732      2/22/21  Northeast  New Hampshire
# 9647  Foot Locker     1185732      2/22/21  Northeast  New Hampshire
#
# 3           City                    Product Price per Unit Units Sold  \
# ...

# %%
# Check Data Types
df2.dtypes
# Out:
# 3
# Retailer            object
# Retailer ID         object
# Invoice Date        object
# Region              object
# State               object
# City                object
# Product             object
# Price per Unit      object
# Units Sold          object
# Total Sales         object
# Operating Profit    object
# Operating Margin    object
# Sales Method        object
# dtype: object

# %%
# Change "Invoice Date" to datetime
pd.to_datetime(df2['Invoice Date'])
# Out:
# 0      2020-01-01
# 1      2020-01-02
# 2      2020-01-03
# 3      2020-01-04
# 4      2020-01-05
#           ...
# 9643   2021-01-24
# 9644   2021-01-24
# 9645   2021-02-22
# 9646   2021-02-22
# 9647   2021-02-22
# Name: Invoice Date, Length: 9648, dtype: datetime64[ns]

# %%
# Change numeric objects to float
df2['Retailer ID'] = df2['Retailer ID'].astype(float)

# %%
# Check
df2.dtypes
# Out:
# 3
# Retailer             object
# Retailer ID         float64
# Invoice Date         object
# Region               object
# State                object
# City                 object
# Product              object
# Price per Unit       object
# Units Sold           object
# Total Sales          object
# Operating Profit     object
# Operating Margin     object
# Sales Method         object
# dtype: object

# %%
# use .replace() to remove unwanted characters - '$' ',' '%' 
df2['Price per Unit'] = df2['Price per Unit'].replace({'\$':''}, regex=True)
df2['Units Sold'] = df2['Units Sold'].replace({',':''}, regex=True)
df2['Total Sales'] = df2['Total Sales'].replace({'\$':'', ',':''}, regex=True)
df2['Operating Profit'] = df2['Operating Profit'].replace({'\$':'', ',':''}, regex=True)
df2['Operating Margin'] = df2['Operating Margin'].replace({'\%':''}, regex=True)
df2
# Out:
# 3        Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker    1185732.0       1/1/20  Northeast       New York
# 1     Foot Locker    1185732.0       1/2/20  Northeast       New York
# 2     Foot Locker    1185732.0       1/3/20  Northeast       New York
# 3     Foot Locker    1185732.0       1/4/20  Northeast       New York
# 4     Foot Locker    1185732.0       1/5/20  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker    1185732.0      1/24/21  Northeast  New Hampshire
# 9644  Foot Locker    1185732.0      1/24/21  Northeast  New Hampshire
# 9645  Foot Locker    1185732.0      2/22/21  Northeast  New Hampshire
# 9646  Foot Locker    1185732.0      2/22/21  Northeast  New Hampshire
# 9647  Foot Locker    1185732.0      2/22/21  Northeast  New Hampshire
#
# 3           City                    Product Price per Unit Units Sold  \
# ...

# %%
# Continue to change the numeric columns from objects to float 
df2['Price per Unit'] = df2['Price per Unit'].astype(float)
df2['Units Sold'] = df2['Units Sold'].astype(float)
df2['Total Sales'] = df2['Total Sales'].astype(float)
df2['Operating Profit'] = df2['Operating Profit'].astype(float)
df2['Operating Margin'] = df2['Operating Margin'].astype(float)
df2.dtypes
# Out:
# 3
# Retailer             object
# Retailer ID         float64
# Invoice Date         object
# Region               object
# State                object
# City                 object
# Product              object
# Price per Unit      float64
# Units Sold          float64
# Total Sales         float64
# Operating Profit    float64
# Operating Margin    float64
# Sales Method         object
# dtype: object
